# %% [markdown]
# <a href="https://colab.research.google.com/github/riddhiphulari584-cloud/Python-/blob/main/Untitled32.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Creating a tuple
t = (5, 2, 9, 1, 7)

# Using built-in functions
print("Length:", len(t))
print("Maximum value:", max(t))
print("Minimum value:", min(t))

# Using tuple() function
lst = [1, 2, 3]
t2 = tuple(lst)
print("Converted tuple:", t2)
# Out:
# Length: 5
# Maximum value: 9
# Minimum value: 1
# Converted tuple: (1, 2, 3)
