# %% [markdown]
# <a href="https://colab.research.google.com/github/riddhiphulari584-cloud/Python-/blob/main/Untitled31.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Creating a tuple
t = (1, 2, 3)

# Trying to modify (will give error if uncommented)
# t[0] = 10

print("Tuples are immutable (cannot be changed)")

# Deleting tuple
del t
print("Tuple deleted successfully")
# Out:
# Tuples are immutable (cannot be changed)
# Tuple deleted successfully
