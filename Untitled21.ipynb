# %% [markdown]
# <a href="https://colab.research.google.com/github/riddhiphulari584-cloud/Python-/blob/main/Untitled21.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
sum = 0
for i in range(1, 11):
    if i % 2 != 0:
        sum += i

print("Sum of odd numbers:", sum)
# Out:
# Sum of odd numbers: 25
