# %% [markdown]
# <a href="https://colab.research.google.com/github/riddhiphulari584-cloud/Python-/blob/main/Untitled35.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
t = (1, 2, 3)

t = t + (4,)
print(t)
# Out:
# (1, 2, 3, 4)

# %%
t = (10, "Hello", 3.5, True)

print(t)
# Out:
# (10, 'Hello', 3.5, True)

# %%
list1 = [10, 20, 30, 40]

print("Sum =", sum(list1))
# Out:
# Sum = 100

# %%
list1 = [10, 50, 30, 80, 40]

print("Largest =", max(list1))
# Out:
# Largest = 80

# %%
s = {1, 2, 3}

s.add(4)
s.update([5, 6])

print(s)
# Out:
# {1, 2, 3, 4, 5, 6}

# %%
from array import *

arr = array('i', [1, 2, 3, 4, 5])

arr.reverse()
print(arr)
# Out:
# array('i', [5, 4, 3, 2, 1])

# %%
from array import *

arr = array('i', [10, 20, 30, 40, 50])

for i in arr:
    print(i)
# Out:
# 10
# 20
# 30
# 40
# 50
