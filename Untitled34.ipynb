# %% [markdown]
# <a href="https://colab.research.google.com/github/riddhiphulari584-cloud/Python-/blob/main/Untitled34.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
d = {'name': 'Riddhi, 'age': 18}

key = 'age'

if key in d:
    print("Key exists")
else:
    print("Key not found")
# Out:
# Key exists
