# %% [markdown]
# <a href="https://colab.research.google.com/github/riddhiphulari584-cloud/Python-/blob/main/Untitled24.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
str1 = input("Enter a string: ")

if len(str1) < 2:
    print("String is too short")
else:
    new_str = str1[:2] + str1[-2:]
    print("New string:", new_str)
