# %% [markdown]
# <a href="https://colab.research.google.com/github/riddhiphulari584-cloud/Python-/blob/main/Untitled29.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
a = [1, 2, 3]
b = [4, 5]

# Concatenation
c = a + b
print(c)

# Repetition
print(a * 2)

# Length
print(len(c))

# Maximum & Minimum
print(max(c))
print(min(c))
