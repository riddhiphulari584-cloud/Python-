# %% [markdown]
# <a href="https://colab.research.google.com/github/riddhiphulari584-cloud/Python-/blob/main/Untitled15.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
Enter a character :A
Uppercase letter
# Out:
#   File "/tmp/ipykernel_22116/834327566.py", line 1
#     Enter a character :A
#           ^
# SyntaxError: invalid syntax
