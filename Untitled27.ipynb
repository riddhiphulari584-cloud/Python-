# %% [markdown]
# <a href="https://colab.research.google.com/github/riddhiphulari584-cloud/Python-/blob/main/Untitled27.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
lst = [10, 20, 30, 40]

# Update
lst[1] = 25

# Append
lst.append(50)

# Insert
lst.insert(2, 15)

# Delete
lst.remove(30)

print(lst)
# Out:
# [10, 25, 15, 40, 50]
