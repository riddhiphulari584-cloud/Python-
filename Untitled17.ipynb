# %% [markdown]
# <a href="https://colab.research.google.com/github/riddhiphulari584-cloud/Python-/blob/main/Untitled17.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Input character
ch = input("Enter a character: ")

# Check condition
if ch.isupper():
    print("The character is Uppercase alphabet")
elif ch.islower():
    print("The character is Lowercase alphabet")
else:
    print("The character is not an alphabet")
