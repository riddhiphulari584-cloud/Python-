# %% [markdown]
# <a href="https://colab.research.google.com/github/riddhiphulari584-cloud/Python-/blob/main/Untitled18.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Input from user
x = input("Enter something: ")

# Check condition
if x.isdigit():
    print("It is a Number")
elif x.isalpha():
    print("It is a Character")
else:
    print("It is neither number nor character")
